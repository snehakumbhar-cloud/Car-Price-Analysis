# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car_data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# ...

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
#statical information
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [raw]
# 1. what is the average price of all cars in the dataset?

# %%
average = df["Selling_Price"].mean()
print(f"1. The average of all cars in dataset is ${average}")
# Out:
# 1. The average of all cars in dataset is $4.661295681063123

# %% [markdown]
# Average Selling Price:
# The mean selling price of all cars is approximately $4.66 lakhs, providing a baseline for price comparisons

# %% [raw]
# 2. what is most common type in the dataset?

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Fuel_Type'].nunique()
# Out:
# 3

# %%
common_Fuel_type = df['Fuel_Type'].mode()[0]
print(f"2. The most common type is {common_Fuel_type}")
# Out:
# 2. The most common type is Petrol

# %% [markdown]
# Fuel Type Distribution:
# The dataset includes three fuel types — Petrol, Diesel, and CNG. Among these, Petrol is the most common fuel type.

# %% [raw]
# 3. what is the shape of the dataset

# %%
#shape of dataset
print("3. Shape:", df.shape)
# Out:
# 3. Shape: (301, 9)

# %% [markdown]
# Dataset Shape:
# The dataset has 301 rows and 9 columns, indicating a moderately sized dataset suitable for further modeling and visualization.

# %% [raw]
# 4. What are the datatypes of the each items of the datasets

# %%
print("/4. Data type:\n",df.dtypes)
# Out:
# /4. Data type:
#  Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %% [markdown]
# Column Data Types:
#
# Car_Name: object – Categorical text data representing car names.
# Year: int64 – Numerical data indicating the year of manufacture.
# Selling_Price & Present_Price: float64 – Continuous variables representing prices.
# Kms_Driven & Owner: int64 – Discrete numerical features.
# Fuel_Type, Seller_Type, Transmission: object – Categorical features relevant to car characteristics and sales.

# %% [raw]
# 5. How many cars have selling price greater than 8.4

# %%
df["Selling_Price"].unique()
# Out:
# array([ 3.35,  4.75,  7.25,  2.85,  4.6 ,  9.25,  6.75,  6.5 ,  8.75,
#         7.45,  6.85,  7.5 ,  6.1 ,  2.25,  7.75,  3.25,  2.65,  4.9 ,
#         4.4 ,  2.5 ,  2.9 ,  3.  ,  4.15,  6.  ,  1.95,  3.1 ,  2.35,
#         4.95,  5.5 ,  2.95,  4.65,  0.35,  5.85,  2.55,  1.25,  1.05,
#         5.8 , 14.9 , 23.  , 18.  , 16.  ,  2.75,  3.6 ,  4.5 ,  4.1 ,
#        19.99,  6.95, 18.75, 23.5 , 33.  , 19.75,  4.35, 14.25,  3.95,
#         1.5 ,  5.25, 14.5 , 14.73, 12.5 ,  3.49, 35.  ,  5.9 ,  3.45,
#         3.8 , 11.25,  3.51,  4.  , 20.75, 17.  ,  7.05,  9.65,  1.75,
#         1.7 ,  1.65,  1.45,  1.35,  1.2 ,  1.15,  1.11,  1.1 ,  1.  ,
#         0.95,  0.9 ,  0.75,  0.8 ,  0.78,  0.72,  0.65,  0.6 ,  0.55,
#         0.52,  0.51,  0.5 ,  0.48,  0.45,  0.42,  0.4 ,  0.38,  0.31,
#         0.3 ,  0.27,  0.25,  0.2 ,  0.18,  0.17,  0.16,  0.15,  0.12,
#         0.1 ,  5.75,  5.15,  7.9 ,  4.85, 11.75,  3.15,  6.45,  3.5 ,
# ...

# %%
#how many cares have selling price greater than 8.4
x = df[df["Selling_Price"] >=8.4].groupby("Car_Name").size()
print("\n 6. Cars having selling price greater than 8.4\n",x)
# Out:
#  6. Cars having selling price greater than 8.4
#  Car_Name
# ciaz              1
# city             13
# corolla altis     3
# creta             3
# elantra           2
# fortuner         11
# innova            6
# land cruiser      1
# verna             2
# vitara brezza     1
# dtype: int64

# %% [raw]
# 6. Most expensive car in the dataset

# %%
#most expensive car
most_exp_car = df[df['Present_Price'] ==df['Present_Price'].max()]
print("\n 6. car with higest present price:\n",most_exp_car[['Car_Name','Present_Price']])
# Out:
#  6. car with higest present price:
#          Car_Name  Present_Price
# 86  land cruiser           92.6

# %% [raw]
# 7. Check for the null value in  the dataset

# %%
#missing value 
print("\n 7. Missing values:\n", df.isnull().sum())
# Out:
#  7. Missing values:
#  Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [raw]
# 8. Check for the duplicate values in the dataset

# %%
#duplicate values
print("\n 8. Duplicate records:", df.duplicated().sum())
print("\n 8. Duplicate records:", df.duplicated())
# Out:
#  8. Duplicate records: 2
#
#  8. Duplicate records: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 301, dtype: bool

# %%
df[df.duplicated()]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner
# 17      Dealer       Manual      0
# 93      Dealer    Automatic      0

# %%
print(df[df.duplicated(keep=False)])
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 15    ertiga  2016           7.75          10.79       43000    Diesel
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 51  fortuner  2015          23.00          30.61       40000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner
# 15      Dealer       Manual      0
# 17      Dealer       Manual      0
# 51      Dealer    Automatic      0
# 93      Dealer    Automatic      0

# %% [raw]
# 9. Average Kms Driven

# %%
#14 Avg kms Driven
print("\n Average Kma Driven:",df['Kms_Driven'].mean())
# Out:
#  Average Kma Driven: 36947.20598006644

# %% [raw]
# 10. Average Selling Price by car model.

# %%
print("\n 10. Avg Selling Price by Car:\n",df.groupby('Car_Name')['Selling_Price'].mean().sort_values(ascending=False))
# Out:
#  10. Avg Selling Price by Car:
#  Car_Name
# land cruiser           35.000000
# fortuner               18.685455
# innova                 12.777778
# creta                  11.800000
# elantra                11.600000
#                          ...
# Hero Hunk               0.200000
# Hero Super Splendor     0.200000
# Hero  Ignitor Disc      0.200000
# Bajaj  ct 100           0.180000
# Bajaj Discover 125      0.175000
# Name: Selling_Price, Length: 98, dtype: float64

# %% [raw]
# 11. Percentage of cars by fuel type

# %%
fuel_percent = df['Fuel_Type'].value_counts(normalize=True)*100
print("\n 11. Percentage of car by fuel_type:\n",fuel_percent)
# Out:
#  11. Percentage of car by fuel_type:
#  Fuel_Type
# Petrol    79.401993
# Diesel    19.933555
# CNG        0.664452
# Name: proportion, dtype: float64

# %% [raw]
# 12. Number of cars manufactured before 2010

# %%
before_2010 = df[df['Year']<2010].shape[0]
print("\n 12. Cares manufactured before 2010", before_2010)
# Out:
#  12. Cares manufactured before 2010 26

# %% [raw]
# 13. What is the most common number of owners (from the Owner column)?

# %%
print(df['Owner'].unique())
# Out:
# [0 1 3]

# %%
print(df['Owner'].nunique())
# Out:
# 3

# %%
owner_counts = df['Owner'].value_counts()
print(owner_counts)
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
most_common_owner = owner_counts.idxmax()
print("\n 13.Most common number of owners:", most_common_owner)
# Out:
#  13.Most common number of owners: 0

# %% [raw]
# 14.What is the average number of kilometers driven (Kms_Driven)?

# %%
print(df['Kms_Driven'].head())
print(df['Kms_Driven'].dtype)
# Out:
# 0    27000
# 1    43000
# 2     6900
# 3     5200
# 4    42450
# Name: Kms_Driven, dtype: int64
# int64

# %%
average_kms = df['Kms_Driven'].mean()
print("Average kilometers driven:", round(average_kms, 2))
# Out:
# Average kilometers driven: 36947.21

# %% [raw]
# 15. Which car has the highest Present_Price?

# %%
print(df.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
max_price_index = df['Present_Price'].idxmax()
max_price_index
# Out:
# 86

# %%
most_expensive_car = df.loc[max_price_index]
print("Car with the highest Present_Price:")
print(most_expensive_car)
# Out:
# Car with the highest Present_Price:
# Car_Name         land cruiser
# Year                     2010
# Selling_Price            35.0
# Present_Price            92.6
# Kms_Driven              78000
# Fuel_Type              Diesel
# Seller_Type            Dealer
# Transmission           Manual
# Owner                       0
# Name: 86, dtype: object

# %% [raw]
# 16. What is the correlation between Selling_Price, Present_Price, and Kms_Driven?

# %%
print(df[['Selling_Price', 'Present_Price', 'Kms_Driven']].dtypes)
# Out:
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# dtype: object

# %%
correlation_matrix = df[['Selling_Price', 'Present_Price', 'Kms_Driven']].corr()
print(correlation_matrix)
# Out:
#                Selling_Price  Present_Price  Kms_Driven
# Selling_Price       1.000000       0.878983    0.029187
# Present_Price       0.878983       1.000000    0.203647
# Kms_Driven          0.029187       0.203647    1.000000

# %% [raw]
# 17. Which Seller_Type has the highest average Selling_Price?

# %%
print(df[['Seller_Type', 'Selling_Price']].head())
# Out:
#   Seller_Type  Selling_Price
# 0      Dealer           3.35
# 1      Dealer           4.75
# 2      Dealer           7.25
# 3      Dealer           2.85
# 4      Dealer           4.60

# %%
avg_price_by_seller = df.groupby('Seller_Type')['Selling_Price'].mean()
print(avg_price_by_seller)
# Out:
# Seller_Type
# Dealer        6.721692
# Individual    0.870943
# Name: Selling_Price, dtype: float64

# %%
highest_avg_seller = avg_price_by_seller.idxmax()
highest_avg_price = avg_price_by_seller.max()

print(f"Seller_Type with highest average Selling_Price: {highest_avg_seller} ({highest_avg_price:.2f} lakhs)")
# Out:
# Seller_Type with highest average Selling_Price: Dealer (6.72 lakhs)

# %% [raw]
# 18. How many cars are there of each Fuel_Type?

# %%
print(df['Fuel_Type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']

# %%
fuel_counts = df['Fuel_Type'].value_counts()
print("Number of cars by Fuel_Type:")
print(fuel_counts)
# Out:
# Number of cars by Fuel_Type:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %% [raw]
# 19. How many cars have more than one previous owner?

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3])

# %%
more_than_one_owner = df[df['Owner']>1]
more_than_one_owner
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 85    camry  2006            2.5          23.73      142000    Petrol
#
#    Seller_Type Transmission  Owner
# 85  Individual    Automatic      3

# %%
count = len (more_than_one_owner)
print(f"\n 19 .Number of cars with more than one owner: {count}")
# Out:
#  19 .Number of cars with more than one owner: 1

# %%
owner_counts = df['Owner'].value_counts().sort_index()  #distribution chart
owner_counts.plot(kind='bar')
plt.xlabel('Number of  Owner')
plt.ylabel('Number of Cars')
plt.title('Distribution of  Owner')
plt.show()

# %% [raw]
# 20. What are the top 5 most expensive cars in the dataset?

# %%
top_expensive = df.sort_values(by = 'Selling_Price', ascending = False)
top_expensive
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 86         land cruiser  2010          35.00          92.60       78000
# 64             fortuner  2017          33.00          36.23        6000
# 63             fortuner  2015          23.50          35.96       47000
# 51             fortuner  2015          23.00          30.61       40000
# 93             fortuner  2015          23.00          30.61       40000
# ..                  ...   ...            ...            ...         ...
# 196           Activa 3g  2008           0.17           0.52      500000
# 197    Honda CB twister  2010           0.16           0.51       33000
# 198  Bajaj Discover 125  2011           0.15           0.57       35000
# 199      Honda CB Shine  2007           0.12           0.58       53000
# 200    Bajaj Pulsar 150  2006           0.10           0.75       92233
#
#     Fuel_Type Seller_Type Transmission  Owner
# 86     Diesel      Dealer       Manual      0
# ...

# %%
top_5 = top_expensive.head(5)
top_5
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 86  land cruiser  2010           35.0          92.60       78000    Diesel
# 64      fortuner  2017           33.0          36.23        6000    Diesel
# 63      fortuner  2015           23.5          35.96       47000    Diesel
# 51      fortuner  2015           23.0          30.61       40000    Diesel
# 93      fortuner  2015           23.0          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner
# 86      Dealer       Manual      0
# 64      Dealer    Automatic      0
# 63      Dealer    Automatic      0
# 51      Dealer    Automatic      0
# 93      Dealer    Automatic      0

# %% [raw]
# 21. What is the average difference between Present_Price and Selling_Price?

# %%
df['Price_Difference'] = df['Present_Price'] - df['Selling_Price']
df['Price_Difference']
# Out:
# 0      2.24
# 1      4.79
# 2      2.60
# 3      1.30
# 4      2.27
#        ...
# 296    2.10
# 297    1.90
# 298    7.65
# 299    1.00
# 300    0.60
# Name: Price_Difference, Length: 301, dtype: float64

# %%
average_difference = df['Price_Difference'].mean()
print(f"\n 21.Average difference between Present_Price and Selling_Price:{average_difference: .2f} lakhs")
# Out:
#  21.Average difference between Present_Price and Selling_Price: 2.97 lakhs

# %% [raw]
# 22. How many cars are being sold by individual sellers vs dealers?

# %%
df['Selling_Price'].unique()
# Out:
# array([ 3.35,  4.75,  7.25,  2.85,  4.6 ,  9.25,  6.75,  6.5 ,  8.75,
#         7.45,  6.85,  7.5 ,  6.1 ,  2.25,  7.75,  3.25,  2.65,  4.9 ,
#         4.4 ,  2.5 ,  2.9 ,  3.  ,  4.15,  6.  ,  1.95,  3.1 ,  2.35,
#         4.95,  5.5 ,  2.95,  4.65,  0.35,  5.85,  2.55,  1.25,  1.05,
#         5.8 , 14.9 , 23.  , 18.  , 16.  ,  2.75,  3.6 ,  4.5 ,  4.1 ,
#        19.99,  6.95, 18.75, 23.5 , 33.  , 19.75,  4.35, 14.25,  3.95,
#         1.5 ,  5.25, 14.5 , 14.73, 12.5 ,  3.49, 35.  ,  5.9 ,  3.45,
#         3.8 , 11.25,  3.51,  4.  , 20.75, 17.  ,  7.05,  9.65,  1.75,
#         1.7 ,  1.65,  1.45,  1.35,  1.2 ,  1.15,  1.11,  1.1 ,  1.  ,
#         0.95,  0.9 ,  0.75,  0.8 ,  0.78,  0.72,  0.65,  0.6 ,  0.55,
#         0.52,  0.51,  0.5 ,  0.48,  0.45,  0.42,  0.4 ,  0.38,  0.31,
#         0.3 ,  0.27,  0.25,  0.2 ,  0.18,  0.17,  0.16,  0.15,  0.12,
#         0.1 ,  5.75,  5.15,  7.9 ,  4.85, 11.75,  3.15,  6.45,  3.5 ,
# ...

# %%
seller_counts = df['Seller_Type'].value_counts()
print(seller_counts)
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
seller_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['skyblue', 'salmon']) #pie chart
plt.title('Seller Type Distribution')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [raw]
# 23. How many cars were manufactured before 2010?

# %%
cars_before_2010 = df[df['Year'] < 2010]
cars_before_2010
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 14                       dzire  2009           2.25          7.210
# 37                         800  2003           0.35          2.280
# 39                         sx4  2003           2.25          7.980
# 42                         sx4  2008           1.95          7.150
# 47                     wagon r  2006           1.05          4.150
# 54                      innova  2005           2.75         10.210
# 55               corolla altis  2009           3.60         15.040
# 77                     corolla  2004           1.50         12.350
# 84                      innova  2005           3.49         13.460
# 85                       camry  2006           2.50         23.730
# 90               corolla altis  2009           3.80         18.610
# 92                      innova  2005           3.51         13.700
# 94               corolla altis  2008           4.00         22.780
# ...

# %%
count = len(cars_before_2010)
print(f"\n 23. Number of cars manufactured before 2010: {count}")
# Out:
#  23. Number of cars manufactured before 2010: 26

# %%
df['Year'].value_counts().sort_index().plot(kind = 'bar', color = 'slateblue')
plt.title('Car Manufacturing Year Distribution')
plt.xlabel('Year')
plt.ylabel('Number of Cars')
plt.tight_layout()
plt.show()

# %% [raw]
# 24. Which year has the highest number of car listings?

# %%
print(df.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner',
#        'Price_Difference'],
#       dtype='object')

# %%
year_counts = df['Year'].value_counts()
print(year_counts)
# Out:
# Year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2005     4
# 2006     4
# 2007     2
# 2003     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
most_listed_year = year_counts.idxmax()
listing_count = year_counts.max()
print(f"\n 24. The year with the highest number of car listings is {most_listed_year}, with {listing_count} listings.")
# Out:
#  24. The year with the highest number of car listings is 2015, with 61 listings.

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Year', palette='coolwarm')
plt.title('Car Listings by Year')
plt.xlabel('Manufacturing Year')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sneha\AppData\Local\Temp\ipykernel_13684\1841367899.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Year', palette='coolwarm')

# %% [raw]
# 25. What percentage of cars are using diesel vs petrol vs CNG?

# %%
print(df['Fuel_Type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']

# %%
fuel_counts = df['Fuel_Type'].value_counts()
print(fuel_counts)
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
total_cars = fuel_counts.sum()
print(total_cars)
# Out:
# 301

# %%
fuel_percentages = (fuel_counts /total_cars)*100
print(fuel_percentages.round(1))
# Out:
# Fuel_Type
# Petrol    79.4
# Diesel    19.9
# CNG        0.7
# Name: count, dtype: float64

# %%
fuel_percentages.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['red', 'green', 'yellow'])
plt.title('Fuel Type Distribution')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [raw]
# 26. What is the highest and lowest Kms_Driven for each fuel type?

# %%
print(df['Fuel_Type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']

# %%
max_kms = df.groupby('Fuel_Type')['Kms_Driven'].max()
min_kms = df.groupby('Fuel_Type')['Kms_Driven'].min()
print("Maximum Kms_Driven by Fuel Type:")
print(max_kms)
print("\n Minimum Kms_Driven by fuel Type:")
print(min_kms)
# Out:
# Maximum Kms_Driven by Fuel Type:
# Fuel_Type
# CNG        49998
# Diesel    197176
# Petrol    500000
# Name: Kms_Driven, dtype: int64
#
#  Minimum Kms_Driven by fuel Type:
# Fuel_Type
# CNG       35500
# Diesel     2071
# Petrol      500
# Name: Kms_Driven, dtype: int64

# %%
kms_summary = pd.DataFrame({
    'Max_Kms_Driven': max_kms,
    'Min_Kms_Driven': min_kms
})
print(kms_summary)
# Out:
#            Max_Kms_Driven  Min_Kms_Driven
# Fuel_Type
# CNG                 49998           35500
# Diesel             197176            2071
# Petrol             500000             500

# %% [raw]
# 27. How many cars were sold with exactly 0 previous owners?

# %%
print(df['Owner'].unique())
# Out:
# [0 1 3]

# %%
zero_owner_cars = df[df['Owner'] == 0]
zero_owner_cars
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Price_Difference
# 0        Dealer       Manual      0              2.24
# ...

# %%
num_zero_owner = zero_owner_cars.shape[0]
print(f"\n 27. Number of cars with 0 previous owners:{num_zero_owner}")
# Out:
#  27. Number of cars with 0 previous owners:290

# %% [raw]
# 28. How many unique combinations of Fuel_Type, Seller_Type, and Transmission exist?

# %%
combo_df = df[['Fuel_Type', 'Seller_Type', 'Transmission']]
combo_df
# Out:
#     Fuel_Type Seller_Type Transmission
# 0      Petrol      Dealer       Manual
# 1      Diesel      Dealer       Manual
# 2      Petrol      Dealer       Manual
# 3      Petrol      Dealer       Manual
# 4      Diesel      Dealer       Manual
# ..        ...         ...          ...
# 296    Diesel      Dealer       Manual
# 297    Petrol      Dealer       Manual
# 298    Petrol      Dealer       Manual
# 299    Diesel      Dealer       Manual
# 300    Petrol      Dealer       Manual
#
# [301 rows x 3 columns]

# %%
unique_combos = combo_df.drop_duplicates()
unique_combos
# Out:
#    Fuel_Type Seller_Type Transmission
# 0     Petrol      Dealer       Manual
# 1     Diesel      Dealer       Manual
# 12    Petrol      Dealer    Automatic
# 18       CNG      Dealer       Manual
# 27    Petrol  Individual       Manual
# 50    Diesel      Dealer    Automatic
# 53    Diesel  Individual    Automatic
# 85    Petrol  Individual    Automatic

# %%
num_unique_combos = unique_combos.shape[0]
print(f"\n 28. Number of unique combinations:{num_unique_combos}")
# Out:
#  28. Number of unique combinations:8

# %%
print(unique_combos)
# Out:
#    Fuel_Type Seller_Type Transmission
# 0     Petrol      Dealer       Manual
# 1     Diesel      Dealer       Manual
# 12    Petrol      Dealer    Automatic
# 18       CNG      Dealer       Manual
# 27    Petrol  Individual       Manual
# 50    Diesel      Dealer    Automatic
# 53    Diesel  Individual    Automatic
# 85    Petrol  Individual    Automatic

# %% [raw]
# 29. What is the average Selling_Price of cars that have more than 2 previous owners?

# %%
print(df['Owner'].unique())
# Out:
# [0 1 3]

# %%
more_than_2_owners = df[df['Owner'] > 2]
more_than_2_owners
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 85    camry  2006            2.5          23.73      142000    Petrol
#
#    Seller_Type Transmission  Owner  Price_Difference
# 85  Individual    Automatic      3             21.23

# %%
avg_price = more_than_2_owners['Selling_Price'].mean()
print(f"\n 29. Average Selling_Price for cars with more than 2 previous owners: {avg_price:.2f} lakhs")
# Out:
#  29. Average Selling_Price for cars with more than 2 previous owners: 2.50 lakhs

# %% [raw]
# 30. Are there any cars where Selling_Price is greater than Present_Price?

# %%
profitable_resales = df[df['Selling_Price'] > df['Present_Price']]
profitable_resales
# Out:
# Empty DataFrame
# Columns: [Car_Name, Year, Selling_Price, Present_Price, Kms_Driven, Fuel_Type, Seller_Type, Transmission, Owner]
# Index: []

# %%
print(profitable_resales)
# Out:
# Empty DataFrame
# Columns: [Car_Name, Year, Selling_Price, Present_Price, Kms_Driven, Fuel_Type, Seller_Type, Transmission, Owner]
# Index: []

# %%
print(f"\n 30. Number of cars sold above Presen_Price: {len(profitable_resales)}")
# Out:
#  30. Number of cars sold above Presen_Price: 0

# %%
plt.scatter(df['Present_Price'], df['Selling_Price'], alpha = 0.6)
plt.xlabel('Present Price')
plt.ylabel('Selling Price')
plt.title('Selling vs Present Price')

# plt.scatter(profitable_resales['Present_Price'], profitable_resales['Selling_Price'],color ='red')
plt.show()
